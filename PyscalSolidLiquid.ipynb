# %% [markdown]
# ## Distinction of solid and liquid

# %%
import os
import pyiron
from ase.io import read
import pyscal.core as pc
import matplotlib.pyplot as plt
import numpy as np

# %%
pr = pyiron.Project('ADIS')

# %%
pr.job_table()
# Out:
#     id    status chemicalformula                       job  \
# 0    2  finished           H8192                   Nucleus
# 1    4  finished           H3980                Si_1400_20
# 2    5  finished           H1529   S5_s00_n130_r1024_720_5
# 3    6  finished           H1980                Fe_1050_20
# 4    7  finished           H1980                Fe_1350_20
# 5    8  finished           H3995                 Si_1000_5
# 6    9  finished           H1980                 Cu_720_20
# 7   10  finished           H2000                  Cu_400_0
# 8   11  finished           H4000                  Mg_900_0
# 9   12  finished           H4000                  Mg_500_0
# 10  13  finished           H1534   S5_s00_n130_r1024_720_0
# 11  15  finished           H3995                  Mg_700_5
# 12  16  finished           H3980                Si_1000_20
# 13  17  finished           H1554   S5_s00_n130_r1024_560_5
# 14  18  finished           H1584   S5_s00_n130_r1024_400_0
# 15  19  finished           H1980                 Cu_400_20
# 16  20  finished           H1995                 Fe_1350_5
# 17  21  finished           H3995                 Mg_1000_5
# 18  22  finished           H4000                 Si_1400_0
# 19  23  finished           H2000                 Fe_1350_0
# 20  24  finished           H4000                  Mg_700_0
# 21  26  finished           H1995                 Fe_1050_5
# 22  27  finished           H3980                Mg_1000_20
# 23  28  finished           H2000                  Cu_560_0
# 24  29  finished           H2000                  Fe_750_0
# 25  30  finished           H1995                  Cu_400_5
# 26  31  finished           H1579   S5_s00_n130_r1024_400_5
# 27  32  finished           H1980                 Fe_750_20
# 28  33  finished           H1980                 Cu_560_20
# 29  34  finished           H2000                  Cu_720_0
# 30  35  finished           H3980                 Mg_500_20
# 31  36  finished           H3980                 Mg_700_20
# 32  38  finished           H3995                  Mg_500_5
# 33  39  finished            H500                    Liquid
# 34  40  finished           H1995                  Cu_560_5
# 35  41  finished           H1510  S5_s00_n130_r1024_720_20
# 36  42  finished           H3980                 Mg_900_20
# 37  43  finished           H2000                 Fe_1050_0
# 38  44  finished           H1559   S5_s00_n130_r1024_560_0
# 39  45  finished           H4000                 Mg_1000_0
# 40  46  finished           H1534  S5_s00_n130_r1024_560_20
# 41  47  finished           H3995                 Si_1400_5
# 42  48  finished           H1995                  Cu_720_5
# 43  49  finished           H1995                  Fe_750_5
# 44  50  finished           H4000                 Si_1000_0
# 45  51  finished           H1559  S5_s00_n130_r1024_400_20
# 46  53  finished           H3995                  Mg_900_5
# 47  56  finished          Cu1995           Cu_minimization
#
#                        subjob    projectpath project  \
# 0                    /Nucleus  /home/jovyan/   ADIS/
# 1                 /Si_1400_20  /home/jovyan/   ADIS/
# 2    /S5_s00_n130_r1024_720_5  /home/jovyan/   ADIS/
# 3                 /Fe_1050_20  /home/jovyan/   ADIS/
# 4                 /Fe_1350_20  /home/jovyan/   ADIS/
# 5                  /Si_1000_5  /home/jovyan/   ADIS/
# 6                  /Cu_720_20  /home/jovyan/   ADIS/
# 7                   /Cu_400_0  /home/jovyan/   ADIS/
# 8                   /Mg_900_0  /home/jovyan/   ADIS/
# 9                   /Mg_500_0  /home/jovyan/   ADIS/
# 10   /S5_s00_n130_r1024_720_0  /home/jovyan/   ADIS/
# 11                  /Mg_700_5  /home/jovyan/   ADIS/
# 12                /Si_1000_20  /home/jovyan/   ADIS/
# 13   /S5_s00_n130_r1024_560_5  /home/jovyan/   ADIS/
# 14   /S5_s00_n130_r1024_400_0  /home/jovyan/   ADIS/
# 15                 /Cu_400_20  /home/jovyan/   ADIS/
# 16                 /Fe_1350_5  /home/jovyan/   ADIS/
# 17                 /Mg_1000_5  /home/jovyan/   ADIS/
# 18                 /Si_1400_0  /home/jovyan/   ADIS/
# 19                 /Fe_1350_0  /home/jovyan/   ADIS/
# 20                  /Mg_700_0  /home/jovyan/   ADIS/
# 21                 /Fe_1050_5  /home/jovyan/   ADIS/
# 22                /Mg_1000_20  /home/jovyan/   ADIS/
# 23                  /Cu_560_0  /home/jovyan/   ADIS/
# 24                  /Fe_750_0  /home/jovyan/   ADIS/
# 25                  /Cu_400_5  /home/jovyan/   ADIS/
# 26   /S5_s00_n130_r1024_400_5  /home/jovyan/   ADIS/
# 27                 /Fe_750_20  /home/jovyan/   ADIS/
# 28                 /Cu_560_20  /home/jovyan/   ADIS/
# 29                  /Cu_720_0  /home/jovyan/   ADIS/
# 30                 /Mg_500_20  /home/jovyan/   ADIS/
# 31                 /Mg_700_20  /home/jovyan/   ADIS/
# 32                  /Mg_500_5  /home/jovyan/   ADIS/
# 33                    /Liquid  /home/jovyan/   ADIS/
# 34                  /Cu_560_5  /home/jovyan/   ADIS/
# 35  /S5_s00_n130_r1024_720_20  /home/jovyan/   ADIS/
# 36                 /Mg_900_20  /home/jovyan/   ADIS/
# 37                 /Fe_1050_0  /home/jovyan/   ADIS/
# 38   /S5_s00_n130_r1024_560_0  /home/jovyan/   ADIS/
# 39                 /Mg_1000_0  /home/jovyan/   ADIS/
# 40  /S5_s00_n130_r1024_560_20  /home/jovyan/   ADIS/
# 41                 /Si_1400_5  /home/jovyan/   ADIS/
# 42                  /Cu_720_5  /home/jovyan/   ADIS/
# 43                  /Fe_750_5  /home/jovyan/   ADIS/
# 44                 /Si_1000_0  /home/jovyan/   ADIS/
# 45  /S5_s00_n130_r1024_400_20  /home/jovyan/   ADIS/
# 46                  /Mg_900_5  /home/jovyan/   ADIS/
# 47           /Cu_minimization  /home/jovyan/   ADIS/
#
#                     timestart                   timestop  totalcputime  \
# 0  2020-11-05 21:11:34.985406                        NaT           NaN
# 1  2020-11-05 21:11:40.585864                        NaT           NaN
# 2  2020-11-05 21:11:43.147042                        NaT           NaN
# 3  2020-11-05 21:11:47.255863                        NaT           NaN
# 4  2020-11-05 21:11:53.247038                        NaT           NaN
# 5  2020-11-05 21:11:59.993315                        NaT           NaN
# 6  2020-11-05 21:12:06.132659                        NaT           NaN
# 7  2020-11-05 21:12:11.172906                        NaT           NaN
# 8  2020-11-05 21:12:18.633493                        NaT           NaN
pyiron@jupyter-pyiron-2dadis-2dworkshop-2d2020-2d3piumz95#1
# 47  pyiron@jupyter-pyiron-2dadis-2dworkshop-2d2020-2d3piumz95#1
#
#                hamilton hamversion parentid masterid
# 0   AtomisticGenericJob      0.2.0     None     None
# 1   AtomisticGenericJob      0.2.0     None     None
# 2   AtomisticGenericJob      0.2.0     None     None
# 3   AtomisticGenericJob      0.2.0     None     None
# 4   AtomisticGenericJob      0.2.0     None     None
# 5   AtomisticGenericJob      0.2.0     None     None
# 6   AtomisticGenericJob      0.2.0     None     None
# 7   AtomisticGenericJob      0.2.0     None     None
# 8   AtomisticGenericJob      0.2.0     None     None
# 9   AtomisticGenericJob      0.2.0     None     None
# 10  AtomisticGenericJob      0.2.0     None     None
# 11  AtomisticGenericJob      0.2.0     None     None
# 12  AtomisticGenericJob      0.2.0     None     None
# 13  AtomisticGenericJob      0.2.0     None     None
# 14  AtomisticGenericJob      0.2.0     None     None
# 15  AtomisticGenericJob      0.2.0     None     None
# 16  AtomisticGenericJob      0.2.0     None     None
# 17  AtomisticGenericJob      0.2.0     None     None
# 18  AtomisticGenericJob      0.2.0     None     None
# 19  AtomisticGenericJob      0.2.0     None     None
# 20  AtomisticGenericJob      0.2.0     None     None
# 21  AtomisticGenericJob      0.2.0     None     None
# 22  AtomisticGenericJob      0.2.0     None     None
# 23  AtomisticGenericJob      0.2.0     None     None
# 24  AtomisticGenericJob      0.2.0     None     None
# 25  AtomisticGenericJob      0.2.0     None     None
# 26  AtomisticGenericJob      0.2.0     None     None
# 27  AtomisticGenericJob      0.2.0     None     None
# 28  AtomisticGenericJob      0.2.0     None     None
# 29  AtomisticGenericJob      0.2.0     None     None
# 30  AtomisticGenericJob      0.2.0     None     None
# 31  AtomisticGenericJob      0.2.0     None     None
# 32  AtomisticGenericJob      0.2.0     None     None
# 33  AtomisticGenericJob      0.2.0     None     None
# 34  AtomisticGenericJob      0.2.0     None     None
# 35  AtomisticGenericJob      0.2.0     None     None
# 36  AtomisticGenericJob      0.2.0     None     None
# 37  AtomisticGenericJob      0.2.0     None     None
# 38  AtomisticGenericJob      0.2.0     None     None
# 39  AtomisticGenericJob      0.2.0     None     None
# 40  AtomisticGenericJob      0.2.0     None     None
# 41  AtomisticGenericJob      0.2.0     None     None
# 42  AtomisticGenericJob      0.2.0     None     None
# 43  AtomisticGenericJob      0.2.0     None     None
# 44  AtomisticGenericJob      0.2.0     None     None
# 45  AtomisticGenericJob      0.2.0     None     None
# 46  AtomisticGenericJob      0.2.0     None     None
# 47               Lammps        0.1     None     None

# %% [markdown]
# We will start with a small configuration in which a small solid cluster is embedded in a liquid.

# %%
job = pr.load("Nucleus")
struct = job.get_structure()

# %% [markdown]
# One good idea is to get the q6 values.

# %% [markdown]
# Pyiron can calculate the q6 values and cluster them. Let's see how that works.

# %%
from pyiron.atomistics.structure.pyscal import get_steinhardt_parameter_job

# %%
q46, cluster = get_steinhardt_parameter_job(job, clustering=True)

# %% [markdown]
# We will switch a bit onto pyscal now. All the features of pyscal are not yet available on pyiron.

# %%
sys = pc.System()
sys.read_inputfile(struct, format="ase")
sys.find_neighbors(method="cutoff", cutoff=0)
sys.calculate_q(6, averaged=True)

# %% [markdown]
# from the previous example, we saw that the solid structures had average q6 roughly above 0.3

# %%
atoms = sys.atoms
for count, atom in enumerate(atoms):
    if atom.get_q(6, averaged=True) > 0.3:
        atom.solid = 1
    else:
        atom.solid = 0
